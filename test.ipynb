# %%
import matplotlib.pyplot as plt
import numpy as np
from fvhoe.hydro import compute_conservatives
from fvhoe.initial_conditions import sinus, square
from fvhoe.solver import EulerSolver

# %%
solver = EulerSolver(w0=square, nx=64, px=3, riemann_solver="advection_upwind")

# %%
solver.rkorder(1, downbeats=[0.5])
# Out:
#   0%|          | 0/1 [00:00]
# 100%|██████████| 1.0/1 [00:02]

# %%
fig, ax = plt.subplots()
param = "rho"
solver.plot_1d_slice(ax, t=0, color="k", param=param, y=0.5, z=0.5)
solver.plot_1d_slice(ax, t=0.5, linestyle="--", param=param, y=0.5, z=0.5)
solver.plot_1d_slice(ax, linestyle="--", param=param, y=0.5, z=0.5)
# Out:
# t=0.00, x=[0.01, 0.99], y=0.50, z=0.50
# t=0.50, x=[0.01, 0.99], y=0.50, z=0.50
# t=1.00, x=[0.01, 0.99], y=0.50, z=0.50

# %%
np.sum(solver.snapshots[0]["rho"][:, 0, 0]) * (solver.h[0] * solver.h[1] * solver.h[2])
# Out:
# 1.5

# %%
np.sum(solver.snapshots[1]["rho"][:, 0, 0]) * (solver.h[0] * solver.h[1] * solver.h[2])
# Out:
# 1.5
