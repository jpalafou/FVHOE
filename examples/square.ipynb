# %%
from fvhoe.initial_conditions import square
from fvhoe.solver import EulerSolver

# %% [markdown]
# 1D square

# %%
solver = EulerSolver(
    w0=square(),
    nx=128,
    px=3,
    riemann_solver="llf",
)
solver.rkorder(1.0)
solver.plot_fields(y=0.5, z=0.5)
# Out:
# 100%|██████████| 1.0/1.0 [00:00]
# (<Figure size 1500x500 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# 2D square

# %%
N = 64
p = 3

solver = EulerSolver(
    w0=square(dims="xy", vx=1, vy=1),
    nx=N,
    ny=N,
    px=p,
    py=p,
    riemann_solver="llf",
    cupy=False,
)
solver.rkorder(1.0, snapshot_dir="../../square", overwrite=True)
solver.plot_fields(z=0.5)
# Out:
# 100%|██████████| 1.0/1.0 [00:05]
# Clearing out snapshot directory ../../square
# Wrote to snapshot directory ../../square
# (<Figure size 640x480 with 6 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >]], dtype=object))
