# %%
from fvhoe.boundary_conditions import BoundaryCondition
from fvhoe.initial_conditions import slotted_disk
from fvhoe.solver import EulerSolver
import matplotlib.pyplot as plt
import numpy as np
# Out:
# WARNING: CuPy is not available. Falling back to NumPy.

# %%
def mx(x, y, z, t):
    yc = y - 0.5
    return -yc


def my(x, y, z, t):
    xc = x - 0.5
    return xc


def E(x, y, z, t):
    xc = x - 0.5
    yc = y - 0.5
    return 1 / (5 / 3 - 1) + 0.5 * (xc**2 + yc**2)


solver = EulerSolver(
    w0=slotted_disk,
    nx=64,
    ny=64,
    px=3,
    py=3,
    bc=BoundaryCondition(
        x="dirichlet",
        y="x",
        x_value={"rho": 1, "E": E, "mx": mx, "my": my, "mz": 0},
        y_value="x",
    ),
    riemann_solver="advection_upwind",
    fixed_primitive_variables=["vx", "vy", "P"],
    a_posteriori_slope_limiting=True,
    slope_limiter="minmod",
    snapshot_dir="../../snapshots",
    cupy=False,
)

# %%
solver.rkorder(
    2 * np.pi,
    downbeats=[0.5 * np.pi, np.pi, 1.5 * np.pi],
    filename="rotation_of_a_slotted_disk",
)
# Out:
#  25%|██▌       | 1.5707963267948966/6.283185307179586 [01:14]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 solver.rkorder(
#       2     2 * np.pi,
#       3     downbeats=[0.5 * np.pi, np.pi, 1.5 * np.pi],
#       4     filename="rotation_of_a_slotted_disk",
#       5 )
#
# File ~/Desktop/FVHOE/fvhoe/solver.py:785, in EulerSolver.rkorder(self, *args, **kwargs)
#     783     self.ssprk3(*args, **kwargs)
#     784 case _:
# --> 785     self.rk4(*args, **kwargs)
#
# File ~/Desktop/FVHOE/fvhoe/ode.py:225, in ODE.rk4(self, *args, **kwargs)
#     222     return dt, unext
#     224 self.stepper = stepper
# --> 225 self.integrate(*args, **kwargs)
#
# File ~/Desktop/FVHOE/fvhoe/ode.py:103, in ODE.integrate(self, stopping_time, n_timesteps, exact, downbeats, log_every_step, save_snapshots, filename, overwrite)
#     101 # target time actions
#     102 if self.t == target_time or self.t >= stopping_time or log_every_step:
# --> 103     self.snapshot()
#     104     if downbeats and self.t == target_time:
#     105         target_time = downbeats.pop(0)
#
# File ~/Desktop/FVHOE/fvhoe/solver.py:640, in EulerSolver.snapshot(self)
#     636 """
#     637 log a dictionary
#     638 """
#     639 # fv conservatives to fv primitives
# --> 640 w = self.interpolate_primitives_from_conservatives(
#     641     u=self.u,
#     642     p=self.p,
#     643     gw=(
#     644         int(np.ceil(self.p[0] / 2)) * int(self.snapshots_as_fv_averages + 1),
#     645         int(np.ceil(self.p[1] / 2)) * int(self.snapshots_as_fv_averages + 1),
#     646         int(np.ceil(self.p[2] / 2)) * int(self.snapshots_as_fv_averages + 1),
#     647     ),
#     648     fv_average=self.snapshots_as_fv_averages,
#     649 )
#     651 # append conservative variables if dumpall
#     652 if self.dumpall:
#
# File ~/Desktop/FVHOE/fvhoe/solver.py:598, in EulerSolver.interpolate_primitives_from_conservatives(self, u, p, gw, fv_average)
#     596         self.w0_cell_centers_cache[gw] = w0_cell_centers
#     597     for var in self.fixed_primitive_variables:
# --> 598         setattr(w_cell_centers, var, getattr(w0_cell_centers, var))
#     599 if fv_average:
#     600     w = interpolate_fv_averages(w_cell_centers, p=p)
#
# File ~/Desktop/FVHOE/fvhoe/named_array.py:76, in define_NamedArray_class.<locals>.NamedArray.__setattr__(self, name, value)
#      74 def __setattr__(self, name, value):
#      75     if "variable_name_set" in self.__dict__ and name in self.variable_name_set:
# ---> 76         self[self.variable_indices[name], ...] = value
#      77     else:
#      78         super().__setattr__(name, value)
#
# ValueError: could not broadcast input array from shape (70,70,1) into shape (68,68,1)

# %%
fig, ax = plt.subplots(2, 2, sharex=True, sharey=True)

for var, label, idx in zip(
    ["rho", "P", "vx", "vy"],
    [r"$\overline{\rho}$", r"$\overline{P}$", r"$\overline{v}_x$", r"$\overline{v}_y$"],
    [(0, 0), (0, 1), (1, 0), (1, 1)],
):
    im = solver.plot_2d_slice(ax[idx], t=2 * np.pi, param=var, cmap="gnuplot", z=0.5)
    fig.colorbar(im, ax=ax[idx], label=label)

ax[0, 0].set_ylabel("$y$")
ax[1, 0].set_ylabel("$y$")
ax[1, 0].set_xlabel("$x$")
ax[1, 1].set_xlabel("$x$")
# Out:
# t=6.28, x=[0.01, 0.99], y=[0.01, 0.99], z=0.50
# horizontal_axis='x', vertical_axis='y'
# t=6.28, x=[0.01, 0.99], y=[0.01, 0.99], z=0.50
# horizontal_axis='x', vertical_axis='y'
# t=6.28, x=[0.01, 0.99], y=[0.01, 0.99], z=0.50
# horizontal_axis='x', vertical_axis='y'
# t=6.28, x=[0.01, 0.99], y=[0.01, 0.99], z=0.50
# horizontal_axis='x', vertical_axis='y'
# Text(0.5, 0, '$x$')

# %%
for t in [0, 1]:
    m_tot = np.sum(solver.snapshots[0]["w"].rho[:, 0, 0]) * (
        solver.h[0] * solver.h[1] * solver.h[2]
    )
    print(f"Total mass at time {t}: {m_tot}")
# Out:
# Total mass at time 0: 0.015625
# Total mass at time 1: 0.015625

# %%
print(f"min rho at latest snapshot: {np.min(solver.snapshots[-1]['w'].rho)}")
print(f"max rho at latest snapshot: {np.max(solver.snapshots[-1]['w'].rho)}")
# Out:
# min rho at latest snapshot: 0.9948640371781089
# max rho at latest snapshot: 1.9458283833836552
